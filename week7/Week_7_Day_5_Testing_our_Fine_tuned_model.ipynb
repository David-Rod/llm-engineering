# %% [markdown]
# ## Predict Product Prices
#
# ### And now, to evaluate our fine-tuned open source model

# %%
# pip installs

# !pip install -q --upgrade torch==2.5.1+cu124 torchvision==0.20.1+cu124 torchaudio==2.5.1+cu124 --index-url https://download.pytorch.org/whl/cu124
# !pip install -q --upgrade requests==2.32.3 bitsandbytes==0.46.0 transformers==4.48.3 accelerate==1.3.0 datasets==3.2.0 peft==0.14.0 trl==0.14.0 matplotlib wandb
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 908.2/908.2 MB 1.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 34.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 115.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 102.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 60.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 129.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 10.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 40.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 17.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 2.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 6.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 8.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 104.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.6/209.6 MB 6.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 118.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 MB 24.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 34.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 336.6/336.6 kB 2.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 13.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.8/374.8 kB 32.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.9/313.9 kB 27.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 35.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.6/19.6 MB 52.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 16.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 102.9 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.3 which is incompatible.
# google-adk 1.13.0 requires requests<3.0.0,>=2.32.4, but you have requests 2.32.3 which is incompatible.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2024.9.0 which is incompatible.

# %%
# imports

import os
import re
import math
from tqdm import tqdm
from google.colab import userdata
from huggingface_hub import login
import torch
import torch.nn.functional as F
import transformers
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig, set_seed
from datasets import load_dataset, Dataset, DatasetDict
from datetime import datetime
from peft import PeftModel
import matplotlib.pyplot as plt

# %%
# Constants

BASE_MODEL = "meta-llama/Meta-Llama-3.1-8B"
PROJECT_NAME = "pricer"
HF_USER = "david-rod"

# The run itself
RUN_NAME = "2025-09-21_00.12.41"

PROJECT_RUN_NAME = f"{PROJECT_NAME}-{RUN_NAME}"
# REVISION = "e8d637df551603dc86cd7a1598a8f44af4d7ae36" # or REVISION = None
REVISION = None
FINETUNED_MODEL = f"{HF_USER}/{PROJECT_RUN_NAME}"

# Uncomment this line if you wish to use my model
# FINETUNED_MODEL = f"ed-donner/{PROJECT_RUN_NAME}"

# Data

DATASET_NAME = f"{HF_USER}/pricer-data"
# Or just use the one I've uploaded
# DATASET_NAME = "ed-donner/pricer-data"

# Hyperparameters for QLoRA

QUANT_4_BIT = True

# %matplotlib inline

# Used for writing to output in color

GREEN = "\033[92m"
YELLOW = "\033[93m"
RED = "\033[91m"
RESET = "\033[0m"
COLOR_MAP = {"red":RED, "orange": YELLOW, "green": GREEN}

# %% [markdown]
# ### Log in to HuggingFace
#
# If you don't already have a HuggingFace account, visit https://huggingface.co to sign up and create a token.
#
# Then select the Secrets for this Notebook by clicking on the key icon in the left, and add a new secret called `HF_TOKEN` with the value as your token.

# %%
print(FINETUNED_MODEL)
print("REVISION:", REVISION)
# Out:
# david-rod/pricer-2025-09-21_00.12.41
# REVISION: None

# %%
# Log in to HuggingFace

hf_token = userdata.get('HF_TOKEN')
login(hf_token, add_to_git_credential=True)

# %%
dataset = load_dataset(DATASET_NAME)
train = dataset['train']
test = dataset['test']
# Out:
# README.md:   0%|          | 0.00/416 [00:00<?, ?B/s]
# data/train-00000-of-00001.parquet:   0%|          | 0.00/184M [00:00<?, ?B/s]
# data/test-00000-of-00001.parquet:   0%|          | 0.00/909k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/400000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/2000 [00:00<?, ? examples/s]

# %%
test[0]
# Out:
# {'text': "How much does this cost to the nearest dollar?\n\nOEM AC Compressor w/A/C Repair Kit For Ford F150 F-150 V8 & Lincoln Mark LT 2007 2008 - BuyAutoParts NEW\nAs one of the world's largest automotive parts suppliers, our parts are trusted every day by mechanics and vehicle owners worldwide. This A/C Compressor and Components Kit is manufactured and tested to the strictest OE standards for unparalleled performance. Built for trouble-free ownership and 100% visually inspected and quality tested, this A/C Compressor and Components Kit is backed by our 100% satisfaction guarantee. Guaranteed Exact Fit for easy installation 100% BRAND NEW, premium ISO/TS 16949 quality - tested to meet or exceed OEM specifications Engineered for superior durability, backed by industry-leading unlimited-mileage warranty Included in this K\n\nPrice is $",
#  'price': 374.41}

# %% [markdown]
# ## Now load the Tokenizer and Model

# %%
# pick the right quantization (thank you Robert M. for spotting the bug with the 8 bit version!)

if QUANT_4_BIT:
  quant_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_compute_dtype=torch.bfloat16,
    bnb_4bit_quant_type="nf4"
  )
else:
  quant_config = BitsAndBytesConfig(
    load_in_8bit=True,
    bnb_8bit_compute_dtype=torch.bfloat16
  )

# %%
# Load the Tokenizer and the Model

tokenizer = AutoTokenizer.from_pretrained(BASE_MODEL, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"

base_model = AutoModelForCausalLM.from_pretrained(
    BASE_MODEL,
    quantization_config=quant_config,
    device_map="auto",
)
base_model.generation_config.pad_token_id = tokenizer.pad_token_id

# Load the fine-tuned model with PEFT
if REVISION:
  fine_tuned_model = PeftModel.from_pretrained(base_model, FINETUNED_MODEL, revision=REVISION)
else:
  fine_tuned_model = PeftModel.from_pretrained(base_model, FINETUNED_MODEL)


print(f"Memory footprint: {fine_tuned_model.get_memory_footprint() / 1e6:.1f} MB")
# Out:
# tokenizer_config.json:   0%|          | 0.00/50.5k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/73.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/826 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.17G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/185 [00:00<?, ?B/s]
# adapter_config.json:   0%|          | 0.00/753 [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/109M [00:00<?, ?B/s]
# Memory footprint: 5700.6 MB

# %%
fine_tuned_model
# Out:
# PeftModelForCausalLM(
#   (base_model): LoraModel(
#     (model): LlamaForCausalLM(
#       (model): LlamaModel(
#         (embed_tokens): Embedding(128256, 4096)
#         (layers): ModuleList(
#           (0-31): 32 x LlamaDecoderLayer(
#             (self_attn): LlamaAttention(
#               (q_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=64, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=64, out_features=4096, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (k_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=64, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=64, out_features=1024, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (v_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=64, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=64, out_features=1024, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (o_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=64, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=64, out_features=4096, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#             )
#             (mlp): LlamaMLP(
#               (gate_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=14336, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=64, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=64, out_features=14336, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (up_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=14336, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=64, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=64, out_features=14336, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (down_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=14336, out_features=4096, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=14336, out_features=64, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=64, out_features=4096, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (act_fn): SiLU()
#             )
#             (input_layernorm): LlamaRMSNorm((4096,), eps=1e-05)
#             (post_attention_layernorm): LlamaRMSNorm((4096,), eps=1e-05)
#           )
#         )
#         (norm): LlamaRMSNorm((4096,), eps=1e-05)
#         (rotary_emb): LlamaRotaryEmbedding()
#       )
#       (lm_head): Linear(in_features=4096, out_features=128256, bias=False)
#     )
#   )
# )

# %% [markdown]
# # THE MOMENT OF TRUTH!
#
# ## Use the model in inference mode
#
# Remember, GPT-4o had an average error of \$76.
# Llama 3.1 base model had an average error of \$396.
# This human had an error of \$127.
#
# ## Caveat
#
# Keep in mind that prices of goods vary considerably; the model can't predict things like sale prices that it doesn't have any information about.

# %%
def extract_price(s):
    if "Price is $" in s:
      contents = s.split("Price is $")[1]
      contents = contents.replace(',','')
      match = re.search(r"[-+]?\d*\.\d+|\d+", contents)
      return float(match.group()) if match else 0
    return 0

# %%
extract_price("Price is $a fabulous 899.99 or so")
# Out:
# 899.99

# %%
# Original prediction function takes the most likely next token

def model_predict(prompt):
    set_seed(42)
    inputs = tokenizer.encode(prompt, return_tensors="pt").to("cuda")
    attention_mask = torch.ones(inputs.shape, device="cuda")
    outputs = fine_tuned_model.generate(inputs, attention_mask=attention_mask, max_new_tokens=3, num_return_sequences=1)
    response = tokenizer.decode(outputs[0])
    return extract_price(response)

# %%
# An improved prediction function takes a weighted average of the top 3 choices
# This code would be more complex if we couldn't take advantage of the fact
# That Llama generates 1 token for any 3 digit number

top_K = 3

def improved_model_predict(prompt, device="cuda"):
    set_seed(42)
    inputs = tokenizer.encode(prompt, return_tensors="pt").to(device)
    attention_mask = torch.ones(inputs.shape, device=device)

    with torch.no_grad():
        outputs = fine_tuned_model(inputs, attention_mask=attention_mask)
        next_token_logits = outputs.logits[:, -1, :].to('cpu')

    next_token_probs = F.softmax(next_token_logits, dim=-1)
    top_prob, top_token_id = next_token_probs.topk(top_K)
    prices, weights = [], []
    for i in range(top_K):
      predicted_token = tokenizer.decode(top_token_id[0][i])
      probability = top_prob[0][i]
      try:
        result = float(predicted_token)
      except ValueError as e:
        result = 0.0
      if result > 0:
        prices.append(result)
        weights.append(probability)
    if not prices:
      return 0.0, 0.0
    total = sum(weights)
    weighted_prices = [price * weight / total for price, weight in zip(prices, weights)]
    return sum(weighted_prices).item()

# %%
class Tester:

    def __init__(self, predictor, data, title=None, size=250):
        self.predictor = predictor
        self.data = data
        self.title = title or predictor.__name__.replace("_", " ").title()
        self.size = size
        self.guesses = []
        self.truths = []
        self.errors = []
        self.sles = []
        self.colors = []

    def color_for(self, error, truth):
        if error<40 or error/truth < 0.2:
            return "green"
        elif error<80 or error/truth < 0.4:
            return "orange"
        else:
            return "red"

    def run_datapoint(self, i):
        datapoint = self.data[i]
        guess = self.predictor(datapoint["text"])
        truth = datapoint["price"]
        error = abs(guess - truth)
        log_error = math.log(truth+1) - math.log(guess+1)
        sle = log_error ** 2
        color = self.color_for(error, truth)
        title = datapoint["text"].split("\n\n")[1][:20] + "..."
        self.guesses.append(guess)
        self.truths.append(truth)
        self.errors.append(error)
        self.sles.append(sle)
        self.colors.append(color)
        print(f"{COLOR_MAP[color]}{i+1}: Guess: ${guess:,.2f} Truth: ${truth:,.2f} Error: ${error:,.2f} SLE: {sle:,.2f} Item: {title}{RESET}")

    def chart(self, title):
        max_error = max(self.errors)
        plt.figure(figsize=(12, 8))
        max_val = max(max(self.truths), max(self.guesses))
        plt.plot([0, max_val], [0, max_val], color='deepskyblue', lw=2, alpha=0.6)
        plt.scatter(self.truths, self.guesses, s=3, c=self.colors)
        plt.xlabel('Ground Truth')
        plt.ylabel('Model Estimate')
        plt.xlim(0, max_val)
        plt.ylim(0, max_val)
        plt.title(title)
        plt.show()

    def report(self):
        average_error = sum(self.errors) / self.size
        rmsle = math.sqrt(sum(self.sles) / self.size)
        hits = sum(1 for color in self.colors if color=="green")
        title = f"{self.title} Error=${average_error:,.2f} RMSLE={rmsle:,.2f} Hits={hits/self.size*100:.1f}%"
        self.chart(title)

    def run(self):
        self.error = 0
        for i in range(self.size):
            self.run_datapoint(i)
        self.report()

    @classmethod
    def test(cls, function, data):
        cls(function, data).run()

# %%
Tester.test(improved_model_predict, test)
# Out:
# 1: Guess: $282.50 Truth: $374.41 Error: $91.91 SLE: 0.08 Item: OEM AC Compressor w/...
# 2: Guess: $158.38 Truth: $225.11 Error: $66.74 SLE: 0.12 Item: Motorcraft YB3125 Fa...
# 3: Guess: $45.16 Truth: $61.68 Error: $16.52 SLE: 0.09 Item: Dorman Front Washer ...
# 4: Guess: $537.00 Truth: $599.99 Error: $62.99 SLE: 0.01 Item: HP Premium HD Plus T...
# 5: Guess: $27.67 Truth: $16.99 Error: $10.68 SLE: 0.22 Item: Super Switch Pickup ...
# 6: Guess: $7.99 Truth: $31.99 Error: $24.00 SLE: 1.69 Item: Horror Bookmarks, Re...
# 7: Guess: $179.12 Truth: $101.79 Error: $77.33 SLE: 0.31 Item: SK6241 - Stinger 4 G...
# 8: Guess: $312.00 Truth: $289.00 Error: $23.00 SLE: 0.01 Item: Godox ML60Bi LED Lig...
# 9: Guess: $632.00 Truth: $635.86 Error: $3.86 SLE: 0.00 Item: Randall G3 Plus Comb...
# 10: Guess: $82.75 Truth: $65.99 Error: $16.76 SLE: 0.05 Item: HOLDWILL 6 Pack LED ...
# 11: Guess: $297.75 Truth: $254.21 Error: $43.54 SLE: 0.02 Item: Viking Horns 3 Gallo...
# 12: Guess: $263.50 Truth: $412.99 Error: $149.49 SLE: 0.20 Item: CURT 70110 Custom To...
# 13: Guess: $89.94 Truth: $205.50 Error: $115.56 SLE: 0.67 Item: Solar HAMMERED BRONZ...
# 14: Guess: $269.75 Truth: $248.23 Error: $21.52 SLE: 0.01 Item: COSTWAY Electric Tum...
# 15: Guess: $256.75 Truth: $399.00 Error: $142.25 SLE: 0.19 Item: FREE SIGNAL TV Trans...
# 16: Guess: $334.00 Truth: $373.94 Error: $39.94 SLE: 0.01 Item: Bilstein 5100 Monotu...
# 17: Guess: $83.94 Truth: $92.89 Error: $8.95 SLE: 0.01 Item: Sangean K-200 Multi-...
# 18: Guess: $262.50 Truth: $51.99 Error: $210.51 SLE: 2.57 Item: Charles Leonard Magn...
# 19: Guess: $242.00 Truth: $179.00 Error: $63.00 SLE: 0.09 Item: Gigabyte AMD Radeon ...
# 20: Guess: $7.00 Truth: $19.42 Error: $12.42 SLE: 0.88 Item: 3dRose LLC 8 x 8 x 0...
# 21: Guess: $489.75 Truth: $539.95 Error: $50.20 SLE: 0.01 Item: ROKINON 85mm F1.4 Au...
# 22: Guess: $130.88 Truth: $147.67 Error: $16.79 SLE: 0.01 Item: Headlight Assembly C...
# 23: Guess: $25.58 Truth: $24.99 Error: $0.59 SLE: 0.00 Item: ASI NAUTICAL 2.5 Inc...
# 24: Guess: $115.12 Truth: $149.00 Error: $33.88 SLE: 0.07 Item: Behringer TUBE OVERD...
# 25: Guess: $6.01 Truth: $16.99 Error: $10.98 SLE: 0.89 Item: Fun Express Insect F...
# 26: Guess: $13.55 Truth: $7.99 Error: $5.56 SLE: 0.23 Item: WAFJAMF Roller Stamp...
# 27: Guess: $263.00 Truth: $199.99 Error: $63.01 SLE: 0.07 Item: Capulina Tiffany Flo...
# 28: Guess: $262.00 Truth: $251.45 Error: $10.55 SLE: 0.00 Item: Apple Watch Series 6...
# 29: Guess: $157.50 Truth: $231.62 Error: $74.12 SLE: 0.15 Item: ICON 01725 Tandem Ax...
# 30: Guess: $102.88 Truth: $135.00 Error: $32.12 SLE: 0.07 Item: SanDisk 128GB Ultra ...
# 31: Guess: $334.75 Truth: $356.62 Error: $21.87 SLE: 0.00 Item: Velvac - 715427
# 2020...
# 32: Guess: $263.75 Truth: $257.99 Error: $5.76 SLE: 0.00 Item: TCMT Passenger Backr...
# 33: Guess: $14.99 Truth: $27.99 Error: $13.00 SLE: 0.35 Item: Alnicov 63.5MM Brass...
# 34: Guess: $162.62 Truth: $171.20 Error: $8.57 SLE: 0.00 Item: Subaru Forester Outb...
# 35: Guess: $262.00 Truth: $225.00 Error: $37.00 SLE: 0.02 Item: Richmond Auto Uphols...
# 36: Guess: $123.56 Truth: $105.00 Error: $18.56 SLE: 0.03 Item: AP-39 Automotive Pai...
# 37: Guess: $303.50 Truth: $299.99 Error: $3.51 SLE: 0.00 Item: Road Top Wireless Ca...
# 38: Guess: $605.00 Truth: $535.09 Error: $69.91 SLE: 0.02 Item: Gibson Performance E...
# 39: Guess: $14.27 Truth: $12.33 Error: $1.94 SLE: 0.02 Item: Bella Tunno Happy Li...
# 40: Guess: $126.69 Truth: $84.99 Error: $41.70 SLE: 0.16 Item: CANMORE H300 Handhel...
# 41: Guess: $15.05 Truth: $15.99 Error: $0.94 SLE: 0.00 Item: DCPOWER AC Adapter C...
# 42: Guess: $34.97 Truth: $62.44 Error: $27.47 SLE: 0.32 Item: Sharp, Commercial De...
# 43: Guess: $106.00 Truth: $82.99 Error: $23.01 SLE: 0.06 Item: Melissa & Doug Lifel...
# 44: Guess: $393.50 Truth: $599.95 Error: $206.45 SLE: 0.18 Item: Sony SSCS8 2-Way Cen...
# 45: Guess: $175.62 Truth: $194.99 Error: $19.37 SLE: 0.01 Item: ASUS Chromebook CX1,...
# 46: Guess: $372.00 Truth: $344.95 Error: $27.05 SLE: 0.01 Item: FiiO X7 32GB Hi-Res ...
# 47: Guess: $29.73 Truth: $37.99 Error: $8.26 SLE: 0.06 Item: TORRO Leather Case C...
# 48: Guess: $253.00 Truth: $224.35 Error: $28.65 SLE: 0.01 Item: Universal Air Condit...
# 49: Guess: $732.00 Truth: $814.00 Error: $82.00 SLE: 0.01 Item: Street Series Stainl...
# 50: Guess: $385.50 Truth: $439.88 Error: $54.38 SLE: 0.02 Item: Lenovo IdeaPad 3 Lap...
# 51: Guess: $298.75 Truth: $341.43 Error: $42.68 SLE: 0.02 Item: Access Bed Covers To...
# 52: Guess: $16.39 Truth: $46.78 Error: $30.39 SLE: 1.02 Item: G.I. JOE Hasbro 3 3/...
# 53: Guess: $171.00 Truth: $171.44 Error: $0.44 SLE: 0.00 Item: T&S Brass Double Pan...
# 54: Guess: $262.75 Truth: $458.00 Error: $195.25 SLE: 0.31 Item: ZTUOAUMA Fuel Inject...
# 55: Guess: $291.00 Truth: $130.75 Error: $160.25 SLE: 0.63 Item: Hp Prime Graphing Ca...
# 56: Guess: $42.91 Truth: $83.81 Error: $40.90 SLE: 0.43 Item: Lowrance Nmea 2000 2...
# 57: Guess: $162.75 Truth: $386.39 Error: $223.64 SLE: 0.74 Item: Jeep Genuine Accesso...
# 58: Guess: $248.62 Truth: $169.00 Error: $79.62 SLE: 0.15 Item: GODOX CB-06 Hard Car...
# 59: Guess: $9.66 Truth: $17.95 Error: $8.29 SLE: 0.33 Item: Au-Tomotive Gold, IN...
# 60: Guess: $237.38 Truth: $269.00 Error: $31.62 SLE: 0.02 Item: Snailfly Black Roof ...
# 61: Guess: $50.00 Truth: $77.77 Error: $27.77 SLE: 0.19 Item: KING SHA Anti Glare ...
# 62: Guess: $90.12 Truth: $88.99 Error: $1.14 SLE: 0.00 Item: APS Compatible with ...
# 63: Guess: $280.00 Truth: $364.41 Error: $84.41 SLE: 0.07 Item: Wilwood Engineering ...
# 64: Guess: $162.62 Truth: $127.03 Error: $35.59 SLE: 0.06 Item: ACDelco Gold Starter...
# 65: Guess: $598.50 Truth: $778.95 Error: $180.45 SLE: 0.07 Item: UWS Matte Black Heav...
# 66: Guess: $255.25 Truth: $206.66 Error: $48.59 SLE: 0.04 Item: Dell Latitude E5440 ...
# 67: Guess: $59.31 Truth: $35.94 Error: $23.37 SLE: 0.24 Item: (Plug and Play) Spar...
# 68: Guess: $180.50 Truth: $149.00 Error: $31.50 SLE: 0.04 Item: The Ultimate Roadsid...
# 69: Guess: $232.75 Truth: $251.98 Error: $19.23 SLE: 0.01 Item: Brand New 18 x 8.5 R...
# 70: Guess: $159.50 Truth: $160.00 Error: $0.50 SLE: 0.00 Item: Headlight Headlamp L...
# 71: Guess: $33.72 Truth: $39.99 Error: $6.27 SLE: 0.03 Item: Lilo And Stitch Delu...
# 72: Guess: $208.62 Truth: $362.41 Error: $153.79 SLE: 0.30 Item: AC Compressor & A/C ...
# 73: Guess: $262.25 Truth: $344.00 Error: $81.75 SLE: 0.07 Item: House Of Troy Pinnac...
# 74: Guess: $7.99 Truth: $25.09 Error: $17.10 SLE: 1.13 Item: Juno T29 WH Floating...
# 75: Guess: $92.88 Truth: $175.95 Error: $83.07 SLE: 0.40 Item: Sherman GO-PARTS - f...
# 76: Guess: $252.38 Truth: $132.64 Error: $119.74 SLE: 0.41 Item: Roland RPU-3 Electro...
# 77: Guess: $348.75 Truth: $422.99 Error: $74.24 SLE: 0.04 Item: Rockland VMI14 12,00...
# 78: Guess: $147.88 Truth: $146.48 Error: $1.40 SLE: 0.00 Item: Max Advanced Brakes ...
# 79: Guess: $154.25 Truth: $156.83 Error: $2.58 SLE: 0.00 Item: Quality-Built 11030 ...
# 80: Guess: $123.50 Truth: $251.99 Error: $128.49 SLE: 0.50 Item: Lucida LG-510 Studen...
# 81: Guess: $169.50 Truth: $940.33 Error: $770.83 SLE: 2.92 Item: Longacre Aluminum Tu...
# 82: Guess: $68.56 Truth: $52.99 Error: $15.57 SLE: 0.06 Item: Motion Pro Adjustabl...
# 83: Guess: $250.12 Truth: $219.95 Error: $30.18 SLE: 0.02 Item: Glyph Thunderbolt 3 ...
# 84: Guess: $269.50 Truth: $441.03 Error: $171.53 SLE: 0.24 Item: TOYO Open Country MT...
# 85: Guess: $202.50 Truth: $168.98 Error: $33.52 SLE: 0.03 Item: Razer Seiren X USB S...
# 86: Guess: $4.88 Truth: $2.49 Error: $2.39 SLE: 0.27 Item: Happy Birthday to Da...
# 87: Guess: $160.12 Truth: $98.62 Error: $61.50 SLE: 0.23 Item: Little Tikes My Real...
# 88: Guess: $293.50 Truth: $256.95 Error: $36.55 SLE: 0.02 Item: Studio M Peace and H...
# 89: Guess: $11.99 Truth: $30.99 Error: $19.00 SLE: 0.81 Item: MyVolts 12V Power Su...
# 90: Guess: $490.75 Truth: $569.84 Error: $79.09 SLE: 0.02 Item: Dell Latitude 7212 R...
# 91: Guess: $220.62 Truth: $177.99 Error: $42.63 SLE: 0.05 Item: Covermates Contour F...
# 92: Guess: $501.75 Truth: $997.99 Error: $496.24 SLE: 0.47 Item: Westin Black HDX Gri...
# 93: Guess: $301.00 Truth: $219.00 Error: $82.00 SLE: 0.10 Item: Fieldpiece JL2 Job L...
# 94: Guess: $266.00 Truth: $225.55 Error: $40.45 SLE: 0.03 Item: hansgrohe Talis S Mo...
# 95: Guess: $572.50 Truth: $495.95 Error: $76.55 SLE: 0.02 Item: G-Technology G-SPEED...
# 96: Guess: $929.00 Truth: $942.37 Error: $13.37 SLE: 0.00 Item: DreamLine Shower Doo...
# 97: Guess: $3.98 Truth: $1.94 Error: $2.04 SLE: 0.28 Item: Sanctuary Square Bac...
# 98: Guess: $298.50 Truth: $284.34 Error: $14.16 SLE: 0.00 Item: Pelican Protector 17...
# 99: Guess: $162.62 Truth: $171.90 Error: $9.28 SLE: 0.00 Item: Brock Replacement Dr...
# 100: Guess: $282.50 Truth: $144.99 Error: $137.51 SLE: 0.44 Item: Carlinkit Ai Box Min...
# 101: Guess: $316.00 Truth: $470.47 Error: $154.47 SLE: 0.16 Item: StarDot YouTube Live...
# 102: Guess: $41.62 Truth: $66.95 Error: $25.33 SLE: 0.22 Item: Atomic Compatible ME...
# 103: Guess: $57.12 Truth: $117.00 Error: $59.88 SLE: 0.50 Item: Bandai Awakening of ...
# 104: Guess: $252.75 Truth: $172.14 Error: $80.61 SLE: 0.15 Item: Fit System 62135G Pa...
# 105: Guess: $301.00 Truth: $392.74 Error: $91.74 SLE: 0.07 Item: Black Horse Black Al...
# 106: Guess: $17.02 Truth: $16.99 Error: $0.03 SLE: 0.00 Item: Dearsun Twinkle Star...
# 107: Guess: $1.67 Truth: $1.34 Error: $0.33 SLE: 0.02 Item: Pokemon - Gallade Sp...
# 108: Guess: $307.50 Truth: $349.98 Error: $42.48 SLE: 0.02 Item: Ibanez GIO Series Cl...
# 109: Guess: $414.50 Truth: $370.71 Error: $43.79 SLE: 0.01 Item: Set 2 Heavy Duty 12 ...
# 110: Guess: $59.28 Truth: $65.88 Error: $6.60 SLE: 0.01 Item: Hairpin Table Legs 2...
# 111: Guess: $296.00 Truth: $229.99 Error: $66.01 SLE: 0.06 Item: Marada Racing Seat w...
# 112: Guess: $7.04 Truth: $9.14 Error: $2.10 SLE: 0.05 Item: Remington Industries...
# 113: Guess: $367.00 Truth: $199.00 Error: $168.00 SLE: 0.37 Item: Acer Ultrabook, Inte...
# 114: Guess: $348.00 Truth: $109.99 Error: $238.01 SLE: 1.31 Item: ICBEAMER 7 RGB LED H...
# 115: Guess: $496.00 Truth: $570.42 Error: $74.42 SLE: 0.02 Item: R1 Concepts Front Re...
# 116: Guess: $264.50 Truth: $279.99 Error: $15.49 SLE: 0.00 Item: Camplux 2.64 GPM Tan...
# 117: Guess: $18.31 Truth: $30.99 Error: $12.68 SLE: 0.25 Item: KNOKLOCK 10 Pack 3.7...
# 118: Guess: $35.06 Truth: $31.99 Error: $3.07 SLE: 0.01 Item: Valley Enterprises Y...
# 119: Guess: $33.69 Truth: $15.90 Error: $17.79 SLE: 0.52 Item: G9 LED Light 100W re...
# 120: Guess: $104.00 Truth: $45.99 Error: $58.01 SLE: 0.65 Item: ZCHAOZ 4 Lights Anti...
# 121: Guess: $173.00 Truth: $113.52 Error: $59.48 SLE: 0.17 Item: Honeywell Honeywell ...
# 122: Guess: $395.50 Truth: $516.99 Error: $121.49 SLE: 0.07 Item: Patriot Exhaust 1-7/...
# 123: Guess: $158.50 Truth: $196.99 Error: $38.49 SLE: 0.05 Item: Fitrite Autopart New...
# 124: Guess: $20.02 Truth: $46.55 Error: $26.53 SLE: 0.67 Item: Technical Precision ...
# 125: Guess: $262.00 Truth: $356.99 Error: $94.99 SLE: 0.10 Item: Covercraft Carhartt ...
# 126: Guess: $294.50 Truth: $319.95 Error: $25.45 SLE: 0.01 Item: Sennheiser SD Pro 2 ...
# 127: Guess: $106.75 Truth: $96.06 Error: $10.69 SLE: 0.01 Item: Hitachi Mass Air Flo...
# 128: Guess: $297.50 Truth: $190.99 Error: $106.51 SLE: 0.19 Item: AmScope LED Cordless...
# 129: Guess: $48.25 Truth: $257.95 Error: $209.70 SLE: 2.75 Item: Front Left Driver Si...
# 130: Guess: $130.00 Truth: $62.95 Error: $67.05 SLE: 0.51 Item: Premium Replica Hubc...
# 131: Guess: $40.06 Truth: $47.66 Error: $7.60 SLE: 0.03 Item: Excellerations Phoni...
# 132: Guess: $262.50 Truth: $226.99 Error: $35.51 SLE: 0.02 Item: RC4WD BigDog Dual Ax...
# 133: Guess: $299.25 Truth: $359.95 Error: $60.70 SLE: 0.03 Item: Unknown Stage 2 Clut...
# 134: Guess: $42.91 Truth: $78.40 Error: $35.49 SLE: 0.35 Item: Dodge Ram 1500 Mopar...
# 135: Guess: $208.75 Truth: $172.77 Error: $35.98 SLE: 0.04 Item: Pro Comp Alloys Seri...
# 136: Guess: $277.25 Truth: $316.45 Error: $39.20 SLE: 0.02 Item: Detroit Axle - Front...
# 137: Guess: $121.75 Truth: $87.99 Error: $33.76 SLE: 0.10 Item: ECCPP Rear Wheel Axl...
# 138: Guess: $201.50 Truth: $226.63 Error: $25.13 SLE: 0.01 Item: Dell Latitude E6520 ...
# 139: Guess: $41.16 Truth: $31.49 Error: $9.67 SLE: 0.07 Item: F FIERCE CYCLE 251pc...
# 140: Guess: $260.50 Truth: $196.00 Error: $64.50 SLE: 0.08 Item: Flash Furniture 4 Pk...
# 141: Guess: $40.59 Truth: $78.40 Error: $37.81 SLE: 0.42 Item: B&M 30287 Throttle V...
# 142: Guess: $158.75 Truth: $116.25 Error: $42.50 SLE: 0.10 Item: Gates TCK226 PowerGr...
# 143: Guess: $121.62 Truth: $112.78 Error: $8.84 SLE: 0.01 Item: Monroe Shocks & Stru...
# 144: Guess: $39.56 Truth: $27.32 Error: $12.24 SLE: 0.13 Item: Feit Electric 35W EQ...
# 145: Guess: $75.56 Truth: $145.91 Error: $70.35 SLE: 0.42 Item: Yellow Jacket 2806 C...
# 146: Guess: $162.62 Truth: $171.09 Error: $8.47 SLE: 0.00 Item: Garage-Pro Tailgate ...
# 147: Guess: $113.00 Truth: $167.95 Error: $54.95 SLE: 0.15 Item: 3M Perfect It Buffin...
# 148: Guess: $36.94 Truth: $28.49 Error: $8.45 SLE: 0.06 Item: Chinese Style Dollho...
# 149: Guess: $67.62 Truth: $122.23 Error: $54.61 SLE: 0.34 Item: Generic NRG Innovati...
# 150: Guess: $50.19 Truth: $32.99 Error: $17.20 SLE: 0.17 Item: Learning Resources C...
# 151: Guess: $79.06 Truth: $71.20 Error: $7.86 SLE: 0.01 Item: Bosch Automotive 154...
# 152: Guess: $57.78 Truth: $112.75 Error: $54.97 SLE: 0.44 Item: Case of 24-2 Inch Bl...
# 153: Guess: $148.12 Truth: $142.43 Error: $5.69 SLE: 0.00 Item: MOCA Engine Water Pu...
# 154: Guess: $276.50 Truth: $398.99 Error: $122.49 SLE: 0.13 Item: SAREMAS Foot Step Ba...
# 155: Guess: $565.00 Truth: $449.00 Error: $116.00 SLE: 0.05 Item: Gretsch G9210 Square...
# 156: Guess: $90.25 Truth: $189.00 Error: $98.75 SLE: 0.54 Item: NikoMaku Mirror Dash...
# 157: Guess: $146.25 Truth: $120.91 Error: $25.34 SLE: 0.04 Item: Fenix HP25R v2.0 USB...
# 158: Guess: $294.50 Truth: $203.53 Error: $90.97 SLE: 0.14 Item: R&L Racing Heavy Dut...
# 159: Guess: $291.25 Truth: $349.99 Error: $58.74 SLE: 0.03 Item: Garmin GPSMAP 64sx, ...
# 160: Guess: $15.08 Truth: $34.35 Error: $19.27 SLE: 0.62 Item: Brown 5-7/8 X 8-1/2 ...
# 161: Guess: $282.75 Truth: $384.99 Error: $102.24 SLE: 0.09 Item: GAOMON PD2200 Pen Di...
# 162: Guess: $261.50 Truth: $211.00 Error: $50.50 SLE: 0.05 Item: VXMOTOR for 97-03 Fo...
# 163: Guess: $198.88 Truth: $129.00 Error: $69.88 SLE: 0.19 Item: HP EliteBook 2540p I...
# 164: Guess: $35.00 Truth: $111.45 Error: $76.45 SLE: 1.30 Item: Green EPX Mixing Noz...
# 165: Guess: $10.29 Truth: $81.12 Error: $70.83 SLE: 3.94 Item: Box Partners 6 1/4 x...
# 166: Guess: $300.00 Truth: $457.08 Error: $157.08 SLE: 0.18 Item: Vixen Air 1/2 NPT Ai...
# 167: Guess: $83.25 Truth: $49.49 Error: $33.76 SLE: 0.26 Item: Smart Floor Lamp, Mu...
# 168: Guess: $45.59 Truth: $80.56 Error: $34.97 SLE: 0.31 Item: SOZG 324mm Wheelbase...
# 169: Guess: $288.50 Truth: $278.39 Error: $10.11 SLE: 0.00 Item: Mickey Thompson ET S...
# 170: Guess: $301.00 Truth: $364.50 Error: $63.50 SLE: 0.04 Item: Pirelli 106W XL RFT ...
# 171: Guess: $300.75 Truth: $378.99 Error: $78.24 SLE: 0.05 Item: Torklift C3212 Rear ...
# 172: Guess: $199.62 Truth: $165.28 Error: $34.34 SLE: 0.04 Item: Cardone Remanufactur...
# 173: Guess: $144.75 Truth: $56.74 Error: $88.01 SLE: 0.86 Item: Kidde AccessPoint 00...
# 174: Guess: $298.50 Truth: $307.95 Error: $9.45 SLE: 0.00 Item: 3M Protecta Self Ret...
# 175: Guess: $57.44 Truth: $38.00 Error: $19.44 SLE: 0.16 Item: Plantronics Wired He...
# 176: Guess: $66.19 Truth: $53.00 Error: $13.19 SLE: 0.05 Item: Logitech K750 Wirele...
# 177: Guess: $554.00 Truth: $498.00 Error: $56.00 SLE: 0.01 Item: Olympus PEN E-PL9 Bo...
# 178: Guess: $148.12 Truth: $53.99 Error: $94.13 SLE: 1.00 Item: Beck/Arnley Hub & Be...
# 179: Guess: $301.00 Truth: $350.00 Error: $49.00 SLE: 0.02 Item: Eibach Pro-Kit Perfo...
# 180: Guess: $306.00 Truth: $299.95 Error: $6.05 SLE: 0.00 Item: LEGO DC Batman 1989 ...
# 181: Guess: $106.94 Truth: $94.93 Error: $12.01 SLE: 0.01 Item: Kingston Brass Resto...
# 182: Guess: $319.50 Truth: $379.00 Error: $59.50 SLE: 0.03 Item: Polk Vanishing Serie...
# 183: Guess: $263.75 Truth: $299.95 Error: $36.20 SLE: 0.02 Item: Spec-D Tuning LED Pr...
# 184: Guess: $12.43 Truth: $24.99 Error: $12.56 SLE: 0.44 Item: RICHMOND & FINCH Air...
# 185: Guess: $125.12 Truth: $41.04 Error: $84.09 SLE: 1.21 Item: LFA Industries - mm ...
# 186: Guess: $312.50 Truth: $327.90 Error: $15.40 SLE: 0.00 Item: SAUTVS LED Headlight...
# 187: Guess: $20.03 Truth: $10.99 Error: $9.04 SLE: 0.32 Item: 2 Pack Combo Womens ...
# 188: Guess: $15.05 Truth: $14.99 Error: $0.06 SLE: 0.00 Item: Arepa - Venezuelan c...
# 189: Guess: $4.99 Truth: $84.95 Error: $79.96 SLE: 7.10 Item: Schlage Lock Company...
# 190: Guess: $125.62 Truth: $111.00 Error: $14.62 SLE: 0.02 Item: Techni Mobili White ...
# 191: Guess: $190.75 Truth: $123.73 Error: $67.02 SLE: 0.18 Item: Special Lite Product...
# 192: Guess: $366.00 Truth: $557.38 Error: $191.38 SLE: 0.18 Item: Tascam Digital Porta...
# 193: Guess: $79.62 Truth: $95.55 Error: $15.92 SLE: 0.03 Item: Glow Lighting Vista ...
# 194: Guess: $188.00 Truth: $154.00 Error: $34.00 SLE: 0.04 Item: Z3 Wind Deflector, S...
# 195: Guess: $311.50 Truth: $198.99 Error: $112.51 SLE: 0.20 Item: Olympus E-20 5MP Dig...
# 196: Guess: $163.12 Truth: $430.44 Error: $267.31 SLE: 0.93 Item: PHYNEDI 1 1000 World...
# 197: Guess: $12.34 Truth: $45.67 Error: $33.33 SLE: 1.57 Item: YANGHUAN Unstable Un...
# 198: Guess: $295.75 Truth: $249.00 Error: $46.75 SLE: 0.03 Item: Interlogix NetworX T...
# 199: Guess: $32.44 Truth: $42.99 Error: $10.55 SLE: 0.08 Item: Steering Damper,Univ...
# 200: Guess: $111.06 Truth: $181.33 Error: $70.27 SLE: 0.24 Item: Amprobe TIC 410A Hot...
# 201: Guess: $1.96 Truth: $6.03 Error: $4.07 SLE: 0.75 Item: MyCableMart 3.5mm Pl...
# 202: Guess: $35.00 Truth: $29.99 Error: $5.01 SLE: 0.02 Item: OtterBox + Pop Symme...
# 203: Guess: $488.25 Truth: $899.00 Error: $410.75 SLE: 0.37 Item: Dell XPS Desktop ( I...
# 204: Guess: $355.75 Truth: $399.99 Error: $44.24 SLE: 0.01 Item: Franklin Iron Works ...
# 205: Guess: $26.56 Truth: $4.66 Error: $21.90 SLE: 2.51 Item: Avery Legal Dividers...
# 206: Guess: $201.75 Truth: $261.41 Error: $59.66 SLE: 0.07 Item: Moen 8346 Commercial...
# 207: Guess: $176.75 Truth: $136.97 Error: $39.78 SLE: 0.06 Item: Carlisle Versa Trail...
# 208: Guess: $82.12 Truth: $79.00 Error: $3.12 SLE: 0.00 Item: SUNWAYFOTO 44mm Trip...
# 209: Guess: $255.00 Truth: $444.99 Error: $189.99 SLE: 0.31 Item: NanoBeam AC 4 Units ...
# 210: Guess: $407.75 Truth: $411.94 Error: $4.19 SLE: 0.00 Item: WULF 4 Front 2 Rear ...
# 211: Guess: $227.75 Truth: $148.40 Error: $79.35 SLE: 0.18 Item: Alera ALEVABFMC Vale...
# 212: Guess: $237.00 Truth: $244.99 Error: $7.99 SLE: 0.00 Item: YU-GI-OH! Ignition A...
# 213: Guess: $179.75 Truth: $86.50 Error: $93.25 SLE: 0.53 Item: 48 x 36 Extra-Large ...
# 214: Guess: $141.50 Truth: $297.95 Error: $156.45 SLE: 0.55 Item: Dell Latitude D620 R...
# 215: Guess: $602.00 Truth: $399.99 Error: $202.01 SLE: 0.17 Item: acer Aspire 5 Laptop...
# 216: Guess: $111.50 Truth: $599.00 Error: $487.50 SLE: 2.80 Item: Elk 30 by 6-Inch Viv...
# 217: Guess: $70.62 Truth: $105.99 Error: $35.36 SLE: 0.16 Item: Barbie Top Model Dol...
# 218: Guess: $487.50 Truth: $689.00 Error: $201.50 SLE: 0.12 Item: Danby Designer 20-In...
# 219: Guess: $298.00 Truth: $404.99 Error: $106.99 SLE: 0.09 Item: FixtureDisplays® Met...
# 220: Guess: $217.62 Truth: $207.76 Error: $9.87 SLE: 0.00 Item: ACDelco GM Original ...
# 221: Guess: $220.50 Truth: $171.82 Error: $48.68 SLE: 0.06 Item: EBC Premium Street B...
# 222: Guess: $417.50 Truth: $293.24 Error: $124.26 SLE: 0.12 Item: FXR Men's Boost FX J...
# 223: Guess: $299.50 Truth: $374.95 Error: $75.45 SLE: 0.05 Item: SuperATV Scratch Res...
# 224: Guess: $109.12 Truth: $111.99 Error: $2.86 SLE: 0.00 Item: SBU 3 Layer All Weat...
# 225: Guess: $24.95 Truth: $42.99 Error: $18.04 SLE: 0.28 Item: 2 Pack Outdoor Broch...
# 226: Guess: $121.69 Truth: $116.71 Error: $4.98 SLE: 0.00 Item: Monroe Shocks & Stru...
# 227: Guess: $156.00 Truth: $118.61 Error: $37.39 SLE: 0.07 Item: Elements of Design M...
# 228: Guess: $185.00 Truth: $147.12 Error: $37.88 SLE: 0.05 Item: GM Genuine Parts Air...
# 229: Guess: $133.50 Truth: $119.99 Error: $13.51 SLE: 0.01 Item: Baseus USB C Docking...
# 230: Guess: $192.25 Truth: $369.98 Error: $177.73 SLE: 0.43 Item: Whitehall™ Personali...
# 231: Guess: $261.75 Truth: $315.55 Error: $53.80 SLE: 0.03 Item: Pro Circuit Works Pi...
# 232: Guess: $314.50 Truth: $190.99 Error: $123.51 SLE: 0.25 Item: HYANKA 15 1200W Prof...
# 233: Guess: $141.38 Truth: $155.00 Error: $13.62 SLE: 0.01 Item: Bluetooth X6BT Card ...
# 234: Guess: $319.75 Truth: $349.99 Error: $30.24 SLE: 0.01 Item: AIRAID Cold Air Inta...
# 235: Guess: $251.62 Truth: $249.99 Error: $1.63 SLE: 0.00 Item: Bostingner Shower Fa...
# 236: Guess: $57.75 Truth: $42.99 Error: $14.76 SLE: 0.08 Item: PIT66 Front Bumper T...
# 237: Guess: $12.37 Truth: $17.99 Error: $5.62 SLE: 0.12 Item: Caseology Bumpy Comp...
# 238: Guess: $300.50 Truth: $425.00 Error: $124.50 SLE: 0.12 Item: Fleck 2510 Timer Mec...
# 239: Guess: $251.75 Truth: $249.99 Error: $1.76 SLE: 0.00 Item: Haloview MC7108 Wire...
# 240: Guess: $32.06 Truth: $138.23 Error: $106.17 SLE: 2.07 Item: Schmidt Spiele - Man...
# 241: Guess: $297.00 Truth: $414.99 Error: $117.99 SLE: 0.11 Item: Corsa 14333 Tip Kit ...
# 242: Guess: $162.50 Truth: $168.28 Error: $5.78 SLE: 0.00 Item: Hoshizaki FM116A Fan...
# 243: Guess: $266.00 Truth: $199.99 Error: $66.01 SLE: 0.08 Item: BAINUO Antler Chande...
# 244: Guess: $154.12 Truth: $126.70 Error: $27.42 SLE: 0.04 Item: DNA MOTORING Smoke L...
# 245: Guess: $2.89 Truth: $5.91 Error: $3.02 SLE: 0.33 Item: Wera Stainless 3840/...
# 246: Guess: $310.75 Truth: $193.06 Error: $117.69 SLE: 0.22 Item: Celestron - PowerSee...
# 247: Guess: $343.00 Truth: $249.99 Error: $93.01 SLE: 0.10 Item: NHOPEEW Android Car ...
# 248: Guess: $78.00 Truth: $64.12 Error: $13.88 SLE: 0.04 Item: Other Harmonica A)
# F...
# 249: Guess: $262.00 Truth: $114.99 Error: $147.01 SLE: 0.67 Item: Harley Air Filter Ve...
# 250: Guess: $800.00 Truth: $926.00 Error: $126.00 SLE: 0.02 Item: Elite Screens Edge F...
